# %% [markdown]
# # **Урок 8:  ➡️ ПОБИТОВЫЕ ОПЕРАТОРЫ**
#
# ### - **Побитовые операторы (`&`, `|`, `^`, `~`, `<<`, `>>`)**
#
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ## 🧩 **Часть 1: Биты и байты в Python**
#
# В компьютерных науках системы счисления играют ключевую роль, так как все данные внутри компьютера представлены в виде чисел, которые хранятся и обрабатываются в двоичной системе (основание 2). Давайте разберем это подробно.
#
# <br>

# %% [markdown]
# ### **1. Бит (Bit)**
#
# >**Бит** — это минимальная единица информации, которая может принимать только два значения: **0** или **1**.
#
#   - **Физическая реализация**:
#
#     - В электронике бит может быть представлен состоянием транзистора (включен/выключен), уровнем напряжения (высокий/низкий) или направлением намагниченности (север/юг).
#
#     - Например:
#       - `0` → отсутствие сигнала (низкий уровень напряжения).
#       - `1` → наличие сигнала (высокий уровень напряжения).
#
# <br>
#
#   - **Логическое значение**:
#
#     - В программировании бит часто используется для представления логических значений (`False` → `0`, `True` → `1`).
#
# <br>
#
#   - **Пример использования**:
#
#     - Биты могут использоваться для флагов, где каждое значение определяет состояние конкретного параметра. Например:
#       ```python
#       FLAG_A = 0b0001  # Первый флаг
#       FLAG_B = 0b0010  # Второй флаг
#       ```

# %% [markdown]
# <br>
#
# ### **2. Байт (Byte)**
#
# > **Байт** — это группа из **8 битов**, которая является минимальной адресуемой единицей памяти в большинстве компьютерных архитектур.
#
#   - **Диапазон значений**:
#
#     - Минимальное значение: `00000000` → **0** в десятичной системе.
#
#     - Максимальное значение: `11111111` → **255** в десятичной системе (так как $2^8 - 1 = 255$).
#
# <br>
#
#   * **✅ Примеры**:
#
#     - `00000000` → `0`.
#
#     - `00001010` → `10`.
#
#     - `11111111` → `255`.
#
# <br>
#
#   - **Значение байта**:
#
#     - Один байт может представлять:
#
#       - Целое число от 0 до 255.
#
#       - Символ в кодировке ASCII (например, `A` → `65` → `01000001`).
#
#       - Часть более крупных данных (например, один цветовой канал в RGB).

# %% [markdown]
# <br>
#
# ### **3. Представление чисел в разных системах счисления**
#
# Компьютеры работают с числами в двоичной системе, но для удобства программисты также используют другие системы счисления, такие как шестнадцатеричная и восьмеричная.

# %% [markdown]
# #### **Двоичная система (Binary)**
#
# - **Основание**: 2
#
# - **Цифры**: `0` и `1`
#
# - **Обозначение в Python**: добавляется префикс `0b`
#
# <br>
#
#   - **✅ Примеры**:
#
#     - `0b1010` → $1 \cdot 2^3 + 0 \cdot 2^2 + 1 \cdot 2^1 + 0 \cdot 2^0 = 10$
#
#     - `0b1111` → $1 \cdot 2^3 + 1 \cdot 2^2 + 1 \cdot 2^1 + 1 \cdot 2^0 = 15$
#
# <br>
#
#   - **Использование**:
#     - Двоичная система используется для работы с битами и байтами напрямую.
#     - Пример:
#       ```python
#       binary_number = 0b1010  # 10 в десятичной системе
#       print(binary_number)  # Вывод: 10
#       ```

# %% [markdown]
# <br>
#
# #### **Шестнадцатеричная система (Hexadecimal)**
#
# - **Основание**: 16
#
# - **Цифры**: `0–9` и буквы `A–F` (где `A=10`, `B=11`, ..., `F=15`)
#
# - **Обозначение в Python**: добавляется префикс `0x`
#
# <br>
#
#   - **Примеры**:
#     - `0xA` → $10$ в десятичной системе
#
#     - `0xFF` → $15 \cdot 16^1 + 15 \cdot 16^0 = 255$
#
#   - **Использование**:
#
#     - Шестнадцатеричная система используется для компактной записи байтов.
#
#       **Пример:**
#
#       - `0xFF` → `11111111` (255 в двоичной системе).
#
#       - `0x1F` → `00011111` (31 в двоичной системе).
#
# <br>
#
#    **✅ Пример:**
#
# ```python
#       hex_number = 0xFF  # 255 в десятичной системе
#       print(hex_number)  # Вывод: 255
# ```

# %%
# Выполните код:

hex_number = 0xFF  # 255 в десятичной системе
print(hex_number)  # Вывод: 255
# Out:
# 255

# %% [markdown]
# #### **Восьмеричная система (Octal)**
#
# - **Основание**: 8
#
# - **Цифры**: `0–7`
#
# - **Обозначение в Python**: добавляется префикс `0o`
#
#   **Примеры**:
#
#     - `0o10` → $1 \cdot 8^1 + 0 \cdot 8^0 = 8$
#
#     - `0o77` → $7 \cdot 8^1 + 7 \cdot 8^0 = 63$
#
#   - **Использование**:
#
#     - Восьмеричная система реже используется в современном программировании, но может применяться для представления прав доступа в Unix-подобных системах.
#
# **✅ Пример:**
#
# ```python
#     octal_number = 0o77  # 63 в десятичной системе
#     print(octal_number)  # Вывод: 63
# ```

# %%
# Выполните код:
octal_number = 0o77  # 63 в десятичной системе
print(octal_number)  # Вывод: 63

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ### **4. Преобразование между системами счисления**
#
# Python предоставляет встроенные функции для преобразования чисел между системами счисления:
#
# - **`bin()`**: преобразует число в двоичную систему.
#
# - **`hex()`**: преобразует число в шестнадцатеричную систему.
#
# - **`oct()`**: преобразует число в восьмеричную систему.
#
# - **`int()`**: преобразует строку или число в целое число, указывая основание системы счисления.

# %% [markdown]
# <br>
#
# **✅ Примеры**:
#
# - **Преобразование в двоичную систему:**
# ```python
#
#     print(bin(10))  # Вывод: '0b1010'
# ```

# %%
# Выполните код:
print(bin(10))
# Out:
# 0b1010

# %% [markdown]
# - **Преобразование в шестнадцатеричную систему:**
#
# ```python
#
# print(hex(255))  # Вывод: '0xff'
# ```

# %%
# Выполните код:
print(hex(255))
# Out:
# 0xff

# %% [markdown]
# - **Преобразование в восьмеричную систему:**
#
# ```python
#
#     print(oct(63))  # Вывод: '0o77'
# ```

# %%
# Выполните код:
print(oct(63))
# Out:
# 0o77

# %% [markdown]
# - **Преобразование строки в число с указанием системы счисления:**
#
# ```python
#
#     print(int('1010', 2))  # Вывод: 10 (двоичная система)
#     print(int('FF', 16))   # Вывод: 255 (шестнадцатеричная система)
# ```

# %%
# Выполните код:
print(int('1010', 2))
print(int('FF', 16))
# Out:
# 10
# 255

# %% [markdown]
# ### **5. Зачем нужны разные системы счисления?**
#
# 1. **Двоичная система**:
#    - Используется напрямую компьютерами для хранения и обработки данных.
#    - Удобна для работы с битами и байтами.
#
# 2. **Шестнадцатеричная система**:
#    - Компактная запись больших двоичных чисел.
#    - Часто используется в программировании для представления цветов, адресов памяти и других данных.
#
# 3. **Восьмеричная система**:
#    - Реже используется, но может быть полезна в специфических задачах (например, права доступа в Unix).

# %% [markdown]
# #### **Подведём итог:**
#
# **Системы счисления** — это основа представления данных в компьютере. Понимание того, как работают биты, байты и разные системы счисления, позволяет эффективно работать с данными на низком уровне. Это особенно важно при работе с побитовыми операторами, шифрованием, оптимизацией памяти и другими задачами.

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ## 🧩 **Часть 2: Представление чисел в памяти**
#
# <br>
#
# #### **1. Целые числа**
#
# - **Положительные числа**: хранятся в двоичной форме.
#
# **✅ Пример:** `5` → `00000101` (8-битное представление).
#
# <br>
#
# - **Отрицательные числа**: используют **дополнение до двух** (two's complement).
#
#   **Алгоритм:**
#
#   1. Инвертировать все биты числа (заменить 0 ↔ 1).
#
#   2. Добавить 1 к результату.
#
# **✅ Пример:**
#
#   - Число `5` → `00000101`.
#
#   - Инверсия → `11111010`.
#
#   - Добавляем 1 → `11111011` (это `-5` в 8-битном представлении).
#
# <br>
#
# #### **2. Переменная длина целых чисел в Python**
#
# - В Python целые числа имеют **произвольную длину** (нет фиксированного количества битов).
#
# **✅ Пример:**
#
#   - `5` → `...00000101` (бесконечно много ведущих нулей).
#
#   - `-5` → `...11111011` (бесконечно много ведущих единиц).
#
# - **Следствие**: Нет переполнения (в отличие от C++ или Java).

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ## 🧩 **Часть 3: Побитовые операторы в Python**
#
#
# ### **3.1 Побитовые операторы в Python**
#
# > Побитовые операторы работают непосредственно с битами чисел. Они позволяют выполнять логические операции на уровне отдельных битов.
#
# <br>
#
# 📌 **Побитовые операторы:**
#
# | Оператор | Название              | Пример   | Значение | Объяснение                                                                 |
# | -------- | --------------------- | -------- | -------- | --------------------------------------------------------------------------- |
# | `&`      | И (AND)               | `5 & 3`  | 1        | Сравнивает каждый бит двух чисел. Результат равен 1, если оба бита равны 1. |
# | `\|`     | ИЛИ (OR)              | `5 \| 3` | 7        | Результат равен 1, если хотя бы один из битов равен 1.                     |
# | `^`      | Исключающее ИЛИ (XOR) | `5 ^ 3`  | 6        | Результат равен 1, если биты различаются.                                   |
# | `~`      | НЕ (NOT, побитовое)   | `~5`     | -6       | Инвертирует все биты числа (заменяет 0 на 1 и наоборот).                   |
# | `<<`     | Сдвиг влево           | `3 << 1` | 6        | Сдвигает биты числа влево, добавляя нули справа.                           |
# | `>>`     | Сдвиг вправо          | `4 >> 1` | 2        | Сдвигает биты числа вправо, удаляя младшие биты.                           |
#
#
# <br>

# %% [markdown]
# #### **Примеры работы побитовых операций:**

# %% [markdown]
# #### **1. `&` Побитовое 'И'(`AND`)**
#
# - **Логика**: `1 & 1 = 1`, иначе `0`.
#
# - **Применение**: Проверка или сброс отдельных битов.
#
# <br>
#
# **✅ Пример:**
#
# ```python
#     0b1010 (10)
#   & 0b1100 (12)
#   = 0b1000 (8)
#
# ```

# %%
# Выполните код:
0b1010 & 0b1100
# Out:
# 8

# %% [markdown]
# <br>
#
# #### **2. `|` Побитовое 'ИЛИ' (`OR`)**
#
# - **Логика**: `0 | 0 = 0`, иначе `1`.
#
# - **Применение**: Установка битов.
#
# <br>
#
# **✅ Пример:**
#
# ```python
#     0b1010 (10)
#   | 0b1100 (12)
#   = 0b1110 (14)
#
# ```

# %%
# Выполните код:
0b1010 | 0b1100
# Out:
# 14

# %% [markdown]
# <br>
#
# ### **3. `^` Исключающее 'ИЛИ' (`XOR`)**
#
# - **Логика**: `1 ^ 1 = 0`, `0 ^ 0 = 0`, иначе `1`.
#
# - **Применение**: Инверсия битов, шифрование.
#
# <br>
#
# **✅ Пример:**
#
# ```python
#     0b1010 (10)
#   ^ 0b1100 (12)
#   = 0b0110 (6)
#
# ```

# %%
# Выполните код:
0b1010 ^ 0b1100
# Out:
# 6

# %% [markdown]
# <br>
#
# #### **4. `~` Побитовое 'НЕ'(`NOT`)**
#
# - **Логика**: Инвертирует все биты числа.
#
# - Оператор `~` инвертирует **все биты** и даёт **отрицательное** число.
#
# - **Важно**: `~x = -x - 1` в Python.
#
# <br>
#
# **✅ Пример:**
#
# ```python
#   ~0b1010 → -11 (в 4-битном представлении: ~1010 = 0101 → -11 в дополнении до двух).
# ```

# %%
# Выполните код:
~0b1010
# Out:
# -11

# %% [markdown]
# <br>
#
# ### **5. `<<` Сдвиг влево**
#
# - **Логика**: Добавляет `n` нулей справа.
#
# - **Применение**: Быстрое умножение на степени двойки.
#
# <br>
#
# **✅ Пример:**
#
# ```python
#   0b101 (5) << 2 → 0b10100 (20) (эквивалентно умножению на 4).
#
# ```

# %%
# Выполните код:
0b101 << 2
# Out:
# 20

# %% [markdown]
# <br>
#
# #### **6. `>>` Сдвиг вправо**
#
# - **Логика**: Удаляет `n` битов справа.
#   Для отрицательных чисел сохраняет знак (дополняет слева единицами).
#
# - **Применение**: Быстрое деление на степени двойки.
#
# <br>
#
# **✅ Пример:**
#
# ```python
#   0b1010 (10) >> 1 → 0b101 (5).
#   -10 >> 1 → -5 (двоичное представление: ...1111011 → ...1111101).
#
# ```

# %%
# Выполните код:
10 >> 1
# Out:
# 5

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ## 🧩 **Часть 4: Работа с памятью**
#
# <br>
#
# ### **📌 Как это работает в памяти?**
#
# В памяти компьютера числа представлены в виде последовательностей битов. Например, целое число (integer) обычно занимает 32 или 64 бита в зависимости от архитектуры процессора. При выполнении побитовых операций компьютер работает непосредственно с этими битами.

# %% [markdown]
# **Наример:**
#
# - Пусть у нас есть число **5**. В памяти оно выглядит так:
#
# ```python
#     00000000 00000000 00000000 00000101
#
# ```
#
# - Если мы применим побитовый оператор `~` (НЕ), то каждый бит будет инвертирован:
#
# ```python
#     11111111 11111111 11111111 11111010
#
# ```
#
# Из-за особенностей представления чисел в компьютере (дополнительный код для отрицательных чисел), наш результат будет интерпретирован как `-6`.
#
# <br>

# %% [markdown]
# **✅ Пример 1: Упаковка данных**
#
# Представим, что нужно хранить 4 флага в одном байте (8 бит):
#
# ```python
#     # Флаги: [Флаг1, Флаг2, Флаг3, Флаг4]
#     flags = 0b00000000  # Все флаги сброшены
#
#     # Установить Флаг3 (3-й бит, считая с 0)
#     flags |= 1 << 3  # flags = 0b00001000 (8)
#
#     # Проверить Флаг2
#     if flags & (1 << 1):
#         print("Флаг2 активен")
#
#     # Сбросить Флаг3
#     flags &= ~(1 << 3)  # flags = 0b00000000
#
# ```

# %%
# Выполните код:

# %% [markdown]
# **✅ Пример 2: Цвета в формате RGB**
#
# Цвет часто кодируется в 24 битах (по 8 бит на канал):
#
# ```python
#
#     red = 255    # 0b11111111
#     green = 128  # 0b10000000
#     blue = 64    # 0b01000000
#
#     # Упаковка в 24-битное число
#     color = (red << 16) | (green << 8) | blue  # 0xFF8040
#
#     # Распаковка
#     red_unpacked = (color >> 16) & 0xFF
#     green_unpacked = (color >> 8) & 0xFF
#     blue_unpacked = color & 0xFF
#
# ```

# %%
# Выполните код:

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ## 🧩 **Часть 5: Низкоуровневая работа с памятью**
#
# <br>
#
# #### **1. Байтовые строки и буферы**
#
# В Python для работы с сырыми бинарными данными используются:
#
# - **`bytes`**: неизменяемая последовательность байтов.
#
# - **`bytearray`**: изменяемая версия `bytes`.
#
# - **Модуль `struct`**: упаковка/распаковка данных в бинарные форматы.
#
# <br>
#
# **✅ Пример:**
#
# ```python
#
#     # Создание байтовой строки
#     data = bytes([0x48, 0x65, 0x6C, 0x6C, 0x6F])  # b'Hello'
#
#     # Чтение первого байта
#     first_byte = data[0]  # 72 (0x48 → 'H')
#
# ```

# %%
# Выполните код:

# %% [markdown]
# #### **2. Шестнадцатеричное представление**
#
# **✅ Пример:**
#
# ```python
#     number = 255
#     hex_str = hex(number)  # '0xff'
#     bytes_from_hex = bytes.fromhex('deadbeef')  # b'\xde\xad\xbe\xef'
#
# ```

# %%
# Выполните код:

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ### ⚠️ **Часть 6: Подводные камни**
#
# #### **1. Знаковые и беззнаковые числа**
#
# - В Python все целые числа знаковые.
#
# **✅ Пример:**
#
#   ```python
#     # В C++: 0b11111011 (8 бит) = 251 (беззнаковое) или -5 (знаковое).
#     # В Python: 0b11111011 = 251, а -5 представлен как ...11111011.
#   ```
#
# #### **2. Сдвиги и знак**
#
# - Сдвиг вправо (`>>`) для отрицательных чисел заполняет старшие биты единицами:
#
# **✅ Пример:**
#
#   ```python
#     -10 >> 1 = -5  # ...1111011 >> 1 = ...1111101.
#   ```
#
# <br>
#
# **✅  Пример:  выполни побтиово**
#
# ```python
#     a = 5  # 00000101
#     b = 3  # 00000011
#
#     print("AND:", a & b)   # 1
#     print("OR:", a | b)    # 7
#     print("XOR:", a ^ b)   # 6
#     print("NOT a:", ~a)    # -6
#     print("Сдвиг влево:", a << 1)  # 10
#     print("Сдвиг вправо:", b >> 1) # 1
# ```

# %%
# Выполните код:

# %% [markdown]
# <br>
#
# ### 📘 **Подведём итоги урока**
#
# Биты — это основа всего, что происходит в компьютере. Понимание побитовых операций помогает глубже разобраться в работе программ и оптимизировать их.
#
# <br>
#
# **Таблица сравнения логических и побитовых операторов**
#
# | Логика | Побитово | Тип                                          |                      |
# | ------ | -------- | -------------------------------------------- | -------------------- |
# | `and`  | `&`      | Булевы значения vs. Биты                     |                      |
# | `or`   | `\`       | `\`                                           | `True/False` vs. 0/1 |
# | `not`  | `~`      | Логическое отрицание vs. инверсия всех битов |                      |
#
# <br>
#
# Понимание работы битов и байтов критически важно для:
#
# - Оптимизации алгоритмов.
#
# - Работы с сетевыми протоколами, файловыми форматами.
#
# - Шифрования и сжатия данных.
#
# - Взаимодействия с аппаратным уровнем (например, через GPIO на Raspberry Pi).
#
# **Совет:** Используйте побитовые операции только там, где это действительно необходимо. В высокоуровневых задачах они могут усложнить чтение кода.

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ### 🧠 **Задачник 9: Побитовые операторы (`&`, `|`, `^`, `~`, `<<`, `>>`)**
#
# <br>

# %% [markdown]
# #### ➡️  **Задача 1: Побитовое И (`&`)**
#
# **Условие:**
#
# Найдите результат побитового И между 5 и 3.

# %% [markdown]
# **Код:**
#
# ```python
# a = 5  # 0b0101
# b = 3  # 0b0011
# print(a & b)
# ```
#
# **Объяснение:**
#
# Побитово:
#
# ```
#   0101
# & 0011
# = 0001  → 1
# ```

# %% [markdown]
# <br>
#
# #### ➡️  **Задача 2: Побитовое ИЛИ (`|`)**
#
# **Условие:**
#
# Найдите результат побитового ИЛИ между 5 и 3.

# %% [markdown]
# **Код:**
#
# ```python
# print(5 | 3)
# ```
#
# **Объяснение:**
#
# ```
#   0101
# | 0011
# = 0111 → 7
# ```

# %% [markdown]
# <br>
#
# #### ➡️  **Задача 3: Побитовый XOR (`^`)**
#
# **Условие:**
#
# Найдите результат побитового исключающего ИЛИ (XOR) между 5 и 3.

# %% [markdown]
# **Код:**
#
# ```python
# print(5 ^ 3)
# ```
#
# **Объяснение:**
#
# ```
#   0101
# ^ 0011
# = 0110 → 6
# ```

# %% [markdown]
# <br>
#
# #### ➡️  **Задача 4: Побитовое отрицание (`~`)**
#
# **Условие:**
#
# Найдите побитовое отрицание `~5`.

# %% [markdown]
# **Код:**
#
# ```python
# print(~5)
# ```
#
# **Объяснение:**
#
# В Python `~x = -x - 1`.
#
# ```
#   00000101 (5)
# → 11111010 = -6 (доп. код)
# ```

# %% [markdown]
# <br>
#
# #### ➡️  **Задача 5: Сдвиг влево (`<<`)**
#
# **Условие:**
#
# Сдвиньте число 3 на 1 бит влево.

# %% [markdown]
# **Код:**
#
# ```python
# print(3 << 1)
# ```
#
# **Объяснение:**
#
# ```
# 3 = 0011 → сдвиг влево → 0110 = 6
# ```
#
# То же самое, что `3 * 2 = 6`.

# %% [markdown]
# <br>
#
# #### ➡️  **Задача 6: Сдвиг вправо (`>>`)**
#
# **Условие:**
#
# Сдвиньте число 4 на 1 бит вправо.

# %% [markdown]
# **Код:**
#
# ```python
# print(4 >> 1)
# ```
#
# **Объяснение:**
#
# ```
# 4 = 0100 → сдвиг вправо → 0010 = 2
# ```
#
# То же самое, что `4 // 2`.

# %% [markdown]
# <br>
#
# #### ➡️  **Задача 7: Сравните `&` и `and`**
#
# **Условие:**
#
# Покажите разницу между логическим `and` и побитовым `&`.

# %% [markdown]
# **Код:**
#
# ```python
# a = True
# b = False
#
# print(a and b)   # False (логика)
# print(a & b)     # False (бит 1 & 0 = 0)
#
# x = 5
# y = 3
# print(x and y)   # 3 (вернёт последнее True значение)
# print(x & y)     # 1 (битовая операция)
# ```
#
# **Объяснение:**
#
# `and` работает с логикой, `&` — с битами.

# %% [markdown]
# <br>
#
# #### ➡️  **Задача 8: Используйте XOR для "переключения"**
#
# **Условие:**
#
# Поменяйте значение на противоположное по принципу "переключатель".

# %% [markdown]
# **Код:**
#
# ```python
# x = 0
# x ^= 1
# print(x)  # 1
# x ^= 1
# print(x)  # 0
# ```
#
# **Объяснение:**
#
# `XOR` с 1 инвертирует бит: `0 → 1`, `1 → 0`.

# %% [markdown]
# <br>
#
# #### ➡️  **Задача 9: Используйте побитовые операторы для маски**
#
# **Условие:**
#
# Есть число `n = 13` (1101). Сохраните только младшие 2 бита.

# %% [markdown]
# **Код:**
#
# ```python
# n = 13
# mask = 0b11  # 00000011
# print(n & mask)
# ```
#
# **Объяснение:**
#
# ```
#   1101
# & 0011
# = 0001 → 1
# ```

# %% [markdown]
# <br>
#
# #### ➡️  **Задача 10: Сдвиг на несколько битов**
#
# **Условие:**
#
# Сдвиньте число 2 на 3 бита влево и выведите результат.

# %% [markdown]
# **Код:**
#
# ```python
# print(2 << 3)
# ```
#
# **Объяснение:**
#
# ```
# 2 = 0010 → сдвиг влево на 3 → 10000 = 16
# ```
#
# То же самое, что `2 * 2 * 2 * 2 = 16`.

# %% [markdown]
# <br>
#
# ---
#
# <br>
#
#
# ##### 📬 Author:
#
# **Siergej Sobolewski**
#
# [![Email 🚀](https://img.shields.io/badge/Email-s.sobolewski@hotmail.com-blue?logo=protonmail)](mailto:s.sobolewski@hotmail.com)
# [![GitHub](https://img.shields.io/badge/GitHub-SSobol77-blue?logo=github)](https://github.com/SSobol77)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Connect-blue?logo=linkedin)](https://linkedin.com/in/siergej-s-25a16319a)
#
# <br>
